# %%
# Test 1: Import basic libraries
print("✓ Step 1: Testing imports...")
import pandas as pd
import numpy as np
print("  - Pandas version:", pd.__version__)
print("  - NumPy version:", np.__version__)

# Test 2: Test Databricks integration
print("\n✓ Step 2: Testing Databricks...")
from databricks.sdk import WorkspaceClient
client = WorkspaceClient()
print("  - Databricks connection: SUCCESS")

# Test 3: Test database (Unity Catalog)
print("\n✓ Step 3: Testing database access...")
spark.sql("CREATE SCHEMA IF NOT EXISTS banking_agent_db")
spark.sql("USE banking_agent_db")
print("  - Database 'banking_agent_db' created: SUCCESS")

# Test 4: Summary
print("\n" + "="*50)
print("✓ ALL SETUP TESTS PASSED!")
print("="*50)

# %%
# Install all required packages
# %pip install langchain-community==0.0.16
# %pip install langchain-openai==0.1.1
# %pip install langchain-core==0.1.19
# %pip install openai==1.3.1
# pandas, numpy, python-dotenv, scikit-learn already available in runtime
# %pip install mlflow==2.10.0
# %pip install databricks-sql-connector==0.9.0

print("✓ All libraries installed!")

# %%
import os

folders = [
    "/Workspace/Users/molugurikoushik68@gmail.com/banking-agent/data",
    "/Workspace/Users/molugurikoushik68@gmail.com/banking-agent/src",
    "/Workspace/Users/molugurikoushik68@gmail.com/banking-agent/notebooks",
    "/Workspace/Users/molugurikoushik68@gmail.com/banking-agent/tests"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"✓ Created folder: {folder}")

print("\n" + "="*60)
print("✓ All project folders created successfully!")
print("="*60)
print("\nYou can view them in the Workspace sidebar on the left.")
